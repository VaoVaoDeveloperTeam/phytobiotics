# %%
#!python -m spacy download es_core_news_sm

# %%
import re
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

# %%
# Build the document ai client
from google.oauth2 import service_account
credentials = service_account.Credentials.from_service_account_info(creds)

from google.cloud import documentai_v1 as documentai
documentai_client = documentai.DocumentProcessorServiceClient(credentials=credentials)

def process_document(image_path):

    file_extension = image_path.split(".")[-1]

    if file_extension == "jpg" or file_extension == "jpeg":
        mime_type = "image/jpeg"
    elif file_extension == "png":
        mime_type = "image/png"
    elif file_extension == "pdf":
        mime_type = "application/pdf"
    else:
        return {
            "text":""
        }

    with open(image_path, "rb") as image:
        image_content = image.read()

    raw_document = documentai.RawDocument(
            content=image_content,
            mime_type=mime_type,
        )

    request = documentai.ProcessRequest(
        #name='projects/212510393549/locations/us/processors/fedf26f965907f56',
        name='projects/239799364293/locations/us/processors/3fb86e3f5c1eb3fc',
        raw_document=raw_document)

    result = documentai_client.process_document(request=request)

    document = result.document
    text = document.text

    return {
        "text":text
    }

# %%
from openai import OpenAI
from pydantic import BaseModel

# Función para realizar la llamada a la API de OpenAI con system instructions
def synthesize_text(text):

    client = OpenAI()

    system_message = """
    Eres un experto en editar documentos científicos y tu objetivo es combinar varios textos en uno solo, sin perder absolutamente ningún detalle relevante. 

    Instrucciones específicas:
    1. No debes omitir ningún dato, incluso si parece repetitivo. Todos los detalles técnicos, cifras, y datos mencionados deben ser preservados.
    2. Organiza el texto en secciones claras: Introducción, Objetivo, Metodología, Resultados y Conclusiones. Asegúrate de que todas las cifras y resultados estén claramente asociados con sus métodos experimentales correspondientes.
    3. Si hay información similar entre los textos, combínala de manera fluida, pero asegúrate de que cada aspecto del estudio esté representado en el texto final.
    4. No introduzcas suposiciones, todo el contenido debe derivarse directamente de los textos originales.
    5. Mantén un tono formal y preciso, y asegura la coherencia entre las secciones.
    6. El texto debe ser EXTREMADAMENTE detallado como para que cualquiera que lo lea pueda entender todos los aspectos importantes del estudio, incluidos los resultados clave, los métodos experimentales y las conclusiones.
    7. Todo el contenido relevante que no entre dentro de las categorías especificadas, puedes incluirlo en un apartado de Observaciones.
    IMPORTANTE: No elimines información durante el proceso de síntesis. Puedes re-estructurarla, pero no eliminarla.
    IMPORTANTE: Necesito que incluyas ABSOLUTAMENTE TODAS las cifras que dan soporte a los resultados y las conclusiones, así como las cifras que dan contexto.
    IMPORTANTE: No me interesa que resumas el contenido de los textos, sólo que lo estructures adecuadamente.
    IMPORTANTE: Debes ser específico, trata de no realizar generalizaciones. Prefiero que respondas con detalles.
    Incluye el nombre original del trabajo además de su traducción al español.
    Divide las diferentes secciones con ## de Markdown, porque luego lo usaré para splitting.
    """


    # Prompt que será enviado al modelo junto con los textos
    prompt = (
        f"""Dado los siguientes textos provenientes de un proceso de OCR en varios archivos relativos a un trabajo de investigación, genera un solo texto que sintetice toda la información de manera clara y concisa, siguiendo las instrucciones del sistema.
        Textos: {text},
        """
    )
    

    class PaperSynthesis(BaseModel):
        paper_title: str
        synthesis: str



    # Realizar la llamada a la API de Open
        # Realizar la llamada a la API de OpenAI
    completion = client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": f"{system_message}"},
            {
                "role": "user",
                "content": f"{prompt}"
            }
        ],
        seed=42,
        max_tokens=10000,
        temperature=0.05,
        top_p=1,
        n=1,
        response_format=PaperSynthesis
    )
    

    # Extraer la respuesta generada
    synthesized_text = completion.choices[0].message.parsed
    return synthesized_text

# %%
def generate_chunks(research_paper_title,context,text):

   client = OpenAI()

   system_instructions = """
   Eres un experto en la creación de fragmentos optimizados (chunks) para un proceso de Recuperación Augmentada por Generación (RAG). 
   Te proporcionaremos tres elementos:
   1. El texto completo del trabajo de investigación, que podrás utilizar para obtener contexto adicional.
   2. El nombre del trabajo de investigación del cual proviene dicho texto.
   3. Un fragmento específico del texto original.

   Tu tarea será dividir el fragmento proporcionado en uno o más chunks con las siguientes condiciones:
   1. Cada chunk debe tener entre 100 y 150 tokens.
   2. Cada chunk debe empezar con un encabezado que contenga:
      - El nombre del trabajo de investigación.
      - Un breve resumen del contexto del trabajo.

   El formato del encabezado será el siguiente:
   "El siguiente es un fragmento del trabajo: <nombre del trabajo de investigación>, que trata sobre <resumen del contexto>: <chunk>"

   Consideraciones importantes:
   - Los chunks deben ser coherentes por sí mismos y formar una unidad semántica completa.
   - Asegúrate de que cada chunk preserve tanto el contexto relevante como la información clave del texto original.
   - No omitas información importante ni repitas contenido innecesariamente entre los chunks.

   Tu objetivo es garantizar que cada fragmento sea comprensible y mantenga el propósito del texto original.
   IMPORTANTE: NO ELIMINES INFORMACIÓN AL REALIZAR LOS CHUNKS
   IMPORTANTE: Debes ser específico, trata de no realizar generalizaciones. Prefiero que respondas con detalles.
   """

   user_message = f"""
   Texto completo del trabajo de investigación: "{context}"

   Nombre del trabajo de investigación: "{research_paper_title}"

   Fragmento específico del texto original: "{text}"

   Tu tarea es dividir el fragmento proporcionado en chunks de 100 a 120 tokens siguiendo las indicaciones anteriores. 
   Cada chunk debe incluir un encabezado con el nombre del trabajo y un breve resumen del contexto. Asegúrate de que cada chunk sea coherente y forme una unidad semántica completa.
   """

   class SynthesisChunks(BaseModel):
      paper_title: str
      chunks: list[str]



   # Realizar la llamada a la API de Open
      # Realizar la llamada a la API de OpenAI
   completion = client.beta.chat.completions.parse(
      model="gpt-4o",
      messages=[
         {
               "role": "system",
               "content": f"{system_instructions}"},
         {
               "role": "user",
               "content": f"{user_message}"
         }
      ],
      seed=42,
      max_tokens=10000,
      temperature=0.01,
      top_p=1,
      n=1,
      response_format=SynthesisChunks
   )


   # Extraer la respuesta generada
   parsed_chunks = completion.choices[0].message.parsed

   return parsed_chunks

# %%
import io
import time
from openai import OpenAI

client = OpenAI()

def upload_chunk(filename,chunk):
    # Convertir el chunk a binario
    binary_db_chunk = chunk.encode('utf-8')

    # Crear un buffer binario
    buffer = io.BytesIO(binary_db_chunk)

    try:
        # Subir el archivo a OpenAI
        openai_file = client.files.create(
            file=(filename, buffer, "text/plain"),
            purpose="assistants"
        )

        # Intentar hasta 10 veces que el archivo esté procesado
        for i in range(10):
            # Verificar si el archivo está procesado
            if openai_file.status == 'processed':
                # Subir el archivo a vector store
                vector_store_file = client.beta.vector_stores.files.create(
                    vector_store_id="vs_UJzqALumjqTk5ZzN18k4GrjA",
                    file_id=openai_file.id,
                    chunking_strategy={
                        "type":"static",
                        "static":{
                            "max_chunk_size_tokens":200,
                            "chunk_overlap_tokens":50
                        }}
                )
                return vector_store_file  # Regresar el archivo subido
            else:
                time.sleep(0.2)  # Esperar antes de reintentar

        raise TimeoutError("El archivo no fue procesado en el tiempo esperado.")
    
    finally:
        # Cerrar el buffer al finalizar
        buffer.close()

# %% [markdown]
# # LOOP

# %%
from tqdm import tqdm

# Define the root directory (in this case 'data')
root_directory = '../data' ### RESTORE THIS FOLDER

# Get the list of subfolders in the root directory
subfolders = [f.path for f in os.scandir(root_directory) if f.is_dir() and f.name != 'Preguntas orientadoras']

# Function to walk through a subfolder and return all files
def get_files_in_subfolder(subfolder):
    file_list = []
    for root, dirs, files in os.walk(subfolder):
        for file in files:
            file_list.append(os.path.join(root, file))
    return file_list


db_chunks = []

# Iterate over each subfolder and print the list of files in it
for subfolder in tqdm(subfolders[11:], desc="Processing subfolders"):

    subfolder_content = {}
    files_in_subfolder = get_files_in_subfolder(subfolder)
    
    for i,file in enumerate(files_in_subfolder):
        filename = file.split("/")[-1]
        try:
            text = process_document(file)
            content = {
                "filename":filename,
                "ocr_text":text["text"]}
            subfolder_content[str(i)]=content
        except Exception as e:
            print(f"Error processing file {file}: {str(e)}")

    # Once the folder content is obtained, send all data to an LLM for synthesis.
    synthesized_output = synthesize_text(subfolder_content)
    synthesized_dict = synthesized_output.json() # Convert pydantic object into a dictionary

    # Almacenar los diccionarios con la síntesis de cada carpeta en un archivo de texto que será utilizado como msg.
    content = str(synthesized_dict)
    file_path = '../research_studies.txt'
    with open(file_path, 'a', encoding='utf-8') as file:
        file.write(content + '\n')

    # Sintetizar chunks que contengan información de contexto
    research_paper_title = eval(synthesized_dict)['paper_title']
    context = eval(synthesized_dict)['synthesis']
    
    splitted_text = re.split(r'(?<!#)##(?!#)', context) # Se utilizan las marcas de sub titulo markdown para el splitting, ya que cada marca va por sección.
    splitted_text = list(filter(lambda x: len(x.strip()) > 0, splitted_text))

    # Almacenar los diferentes chunks en una lista para luego incluirlos en un vector store
    for text in splitted_text[:]:
        synthetic_chunks = generate_chunks(research_paper_title,context,text)
        chunks = eval(synthetic_chunks.json())['chunks']
        db_chunks.extend(chunks)
# Out:
# Processing subfolders:   0%|          | 0/14 [00:00<?, ?it/s]
# Error processing file ../data/8/PPT-Niti_et_al_Performance_Immune-_Response_White-Shrimp_.Litopenaeus-vannamei._EN--.pdf: 400 Document pages exceed the limit: 15 got 24 [reason: "PAGE_LIMIT_EXCEEDED"
# domain: "documentai.googleapis.com"
# metadata {
#   key: "pages"
#   value: "24"
# }
# metadata {
#   key: "page_limit"
#   value: "15"
# }
# ]
# Processing subfolders: 100%|██████████| 14/14 [11:00<00:00, 47.16s/it]

# %%
# Una vez creados los chunks, súbelos al vector store
for index, db_chunk in enumerate(tqdm(db_chunks[:], desc="Uploading chunks to vector store")):

    try:
        # Subir cada chunk al vector store
        vector_store_file = upload_chunk(filename=f"file_{str(index)}.txt", chunk=db_chunk)
        time.sleep(0.2)  # Esperar antes de continuar para evitar sobre cargar la api

    except Exception as e:
        print(f"Error al subir el chunk {index}: {e}")
# Out:
# Uploading chunks to vector store: 100%|██████████| 170/170 [04:10<00:00,  1.47s/it]

# %%
# Una vez creados los chunks, súbelos al vector store
for index, db_chunk in enumerate(tqdm(db_chunks[:], desc="Uploading chunks to vector store")):

    try:
        # Subir cada chunk al vector store
        vector_store_file = upload_chunk(filename=f"file_{str(index)}.txt", chunk=db_chunk)
        time.sleep(0.2)  # Esperar antes de continuar para evitar sobre cargar la api

    except Exception as e:
        print(f"Error al subir el chunk {index}: {e}")

# %%
# Definimos la variable global para los datos históricos
historic_data = ""
# Intentamos cargar el archivo al importar el módulo
try:
    with open("../research_studies.txt", "r", encoding="utf-8") as file:
        historic_data = file.read()
except FileNotFoundError:
    print("El archivo research_studies.txt no se encontró.")
except Exception as e:
    print(f"Error al leer el archivo: {e}")

# %%
import json

# Path to your txt file
file_path = "../research_studies.txt"

# Open and read the file line by line
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            # Parse each line as a dictionary
            data_dict = json.loads(line)
            # Perform your processing here
            file_name = data_dict['paper_title']
            content = data_dict['synthesis']
            print(data_dict)  # Example print statement to see the dictionary
        except json.JSONDecodeError as e:
            print(f"Error parsing line: {line}")
            print(f"Error message: {e}")
# Out:
# {'paper_title': 'Effect of Sangrovit® Supplementation in Combination with Organic Acids on Stress Response and Diarrhea of Post-Weaning Pigs', 'synthesis': '## Introducción\nEl destete es un evento muy estresante para los lechones debido a un cambio en la dieta, un nuevo entorno y la mezcla con cerdos desconocidos. Además, su sistema inmunológico aún no está completamente desarrollado, lo que hace que la diarrea post-destete (PWD), causada principalmente por E. coli enterotoxigénico (ETEC), sea un problema importante en los lechones destetados. La hipótesis del estudio fue que el uso de Sangrovit® en combinación con una mezcla de ácidos orgánicos podría mitigar el impacto negativo del estrés del destete, mejorar las puntuaciones fecales de los lechones post-destete y reducir la necesidad de tratamientos antibióticos.\n\n## Objetivo\nEvaluar el efecto de la suplementación con Sangrovit® en combinación con ácidos orgánicos sobre la respuesta al estrés y la incidencia de diarrea en lechones post-destete.\n\n## Metodología\n- **Especie:** Lechones (genética PIC, peso corporal 6.64 kg, edad 23 ± 2 días, 50% machos castrados y 50% hembras).\n- **Duración del ensayo:** 8 semanas.\n- **Dieta:** Dietas Pre-Iniciador (23-42 días) e Iniciador (43-77 días) basadas en maíz y harina de soja.\n- **Instalaciones:** 12 corrales por tratamiento, 5 lechones por corral. Los corrales tenían un piso de plástico completamente ranurado, un área de 2.55 m², un comedero lineal de 0.9 m y un bebedero ajustable.\n- **Temperatura ambiente:** Registrada usando un Data Logger.\n- **Parámetros evaluados:**\n  - Incidencia, duración y severidad de la diarrea.\n  - Uso de medicación.\n  - Respuesta al estrés: Se midieron los niveles de cortisol en sangre en los días 0, 3 y 56. Se probaron 24 lechones por tratamiento, los mismos lechones fueron muestreados cada vez.\n\n### Tratamientos\n1. **Control Negativo (NC):** Dieta basal, no suplementada.\n2. **Ácidos Orgánicos (OA):** Dieta basal + 4000 ppm de mezcla de ácidos orgánicos (propiónico, butírico, caprílico y caproico).\n3. **Ácidos Orgánicos + Sangrovit® (OA+SAN):** OA + 100 ppm de Sangrovit® WS en agua durante los primeros 3 días después del destete + 300 ppm de Sangrovit® Extra durante toda la duración del ensayo.\n\n## Resultados\n- **Niveles de cortisol:** La adición de Sangrovit® a la mezcla de ácidos orgánicos redujo la respuesta al estrés en los lechones destetados desde el día 3 en adelante (p ≤ 0.05). En el día 0, los niveles de cortisol no mostraron diferencias significativas entre los tratamientos, lo cual era esperado.\n- **Incidencia de diarrea:** La combinación de Sangrovit® con OA disminuyó la incidencia de diarrea en un 36% en comparación con el control y en un 10% en comparación con OA solo. Los lechones que recibieron OA o la combinación de OA y Sangrovit® se recuperaron más rápido de la diarrea y necesitaron menos antibióticos.\n- **Costos de medicación:** Los costos de medicación fueron un 55% más bajos en el grupo que recibió OA+SAN y un 33% más bajos en el grupo que recibió solo OA en comparación con el grupo de control.\n\n## Conclusiones\nSangrovit® tuvo un efecto positivo adicional sobre el estrés del destete y la diarrea post-destete cuando se combinó con una mezcla de ácidos orgánicos. Se mejoraron el número de casos de diarrea, así como la duración y la necesidad de medicación.\n\n## Observaciones\n- Todas las muestras de sangre se recogieron a la misma hora (por la mañana) para evitar el efecto de la ritmicidad circadiana.\n- El estudio se llevó a cabo en las instalaciones de investigación animal AKEI en Brasil en 2017.'}
# {'paper_title': 'The effects of Sangrovit® Extra Green Line in organic laying production', 'synthesis': '## Introducción\nEl estudio titulado "The effects of Sangrovit® Extra Green Line in organic laying production" se llevó a cabo en el Bio Geflügelhof Deersheim, Alemania, en 2017. Este ensayo de campo se centró en evaluar los efectos del suplemento Sangrovit® Extra Green Line en la producción de huevos orgánicos. El ensayo se realizó en gallinas ponedoras de la especie NOVOgen brown, comenzando en la semana 9 del período de cría y concluyendo en la semana 44 del período de producción.\n\n## Objetivo\nEl objetivo principal del estudio fue investigar los efectos del suplemento Sangrovit® Extra Green Line, administrado a una dosis de 125 ppm, en la producción de huevos orgánicos. Se compararon dos grupos de tratamiento: un grupo de control negativo sin aditivos y un grupo tratado con Sangrovit® Extra Green Line.\n\n## Metodología\n### Diseño del Estudio\n- **Especie:** Gallinas ponedoras NOVOgen brown.\n- **Ubicación:** Bio Geflügelhof Deersheim, Alemania.\n- **Período de Cría:** Semana 9 a 18.\n- **Período de Producción:** Semana 18 a 44.\n- **Tratamientos:**\n  - NC: Control Negativo, sin aditivos.\n  - SEGL: 125 ppm de Sangrovit® Extra Green Line.\n\n### Alimentación\nLa dieta se basó en trigo, maíz, torta de aceite de soja, torta de aceite de girasol, guisantes, gluten de maíz, alfalfa, aceite de soja, minerales y vitaminas.\n\n### Población de Estudio\n- **Período de Cría:**\n  - NC: 24,640 aves.\n  - SEGL: 24,674 aves.\n- **Período de Producción:**\n  - NC: 5,990 aves.\n  - SEGL: 6,000 aves.\n\n## Resultados\n### Uniformidad y Consumo de Alimento\nDurante el período de cría, las aves del grupo SEGL mostraron una mejor uniformidad en comparación con el grupo de control negativo. Aunque al inicio del ensayo las aves suplementadas con Sangrovit® Extra Green Line tenían un menor consumo de alimento, después de un brote de Bronquitis Infecciosa (IB) en la semana 35, este grupo consumió más alimento que el grupo de control negativo.\n\n### Desempeño de Postura\n- **Tasa de Postura Promedio:**\n  - NC: 89%.\n  - SEGL: 91%.\n- **Desempeño durante el Brote de IB:**\n  - NC: Disminución del 10%.\n  - SEGL: Disminución leve, manteniendo un 92% de desempeño.\n\n### Conversión Alimenticia y Mortalidad\n- **Conversión Alimenticia (FCR):**\n  - NC: 2.09.\n  - SEGL: 2.04.\n- **Mortalidad:**\n  - NC: 3.10%.\n  - SEGL: 2.70%.\n\n## Conclusiones\nEl uso de Sangrovit® Extra Green Line en la alimentación de gallinas ponedoras orgánicas resultó en una mejor uniformidad durante el período de cría, un desempeño de postura más consistente, especialmente durante el brote de IB, una mejora en la conversión alimenticia y una mayor viabilidad. Estos resultados sugieren que Sangrovit® Extra Green Line puede ser un aditivo beneficioso en la producción de huevos orgánicos.\n\n## Observaciones\nEl ensayo fue realizado por Phytobiotics Futterzusatzstoffe GmbH, y los resultados no han sido publicados oficialmente. El estudio fue actualizado el 28 de noviembre de 2022.'}
# {'paper_title': 'The Effect of Sangrovit Extra on Performance in Laying Hens Under Heat Stress Conditions - A Field Trial', 'synthesis': '## Introducción\nEl estudio titulado "The Effect of Sangrovit Extra on Performance in Laying Hens Under Heat Stress Conditions - A Field Trial" se llevó a cabo para evaluar el impacto del suplemento SangrovitⓇ Extra en el rendimiento de gallinas ponedoras sometidas a condiciones de estrés por calor. Este ensayo de campo se realizó en Polonia y se centró en la especie Lohmann Brown, un tipo de ave de corral. El estudio no ha sido publicado y se basa en datos crudos disponibles.\n\n## Objetivo\nEl objetivo principal del ensayo fue observar los efectos de SangrovitⓇ Extra en el rendimiento y la mortalidad de las gallinas ponedoras durante un periodo de calor de cuatro semanas. Se buscó determinar si el suplemento podría mejorar la producción de huevos, el peso de los huevos, la mortalidad y el número de huevos vendibles bajo condiciones de estrés térmico.\n\n## Metodología\nEl ensayo se llevó a cabo con 28,600 aves por tratamiento, durante un periodo de 9 semanas (de la semana 62 a la 70). Las aves fueron alimentadas con una dieta basada en harina de soja, maíz, trigo y un 1.25% de premezcla, complementada con aceite de soja. Se establecieron dos grupos de tratamiento:\n1. Control Negativo (NC): sin suplementación.\n2. SangrovitⓇ Extra (SE100): 100 ppm de SangrovitⓇ Extra.\n\nSe registró una curva de temperatura en el gallinero durante el ensayo para monitorear las condiciones de calor.\n\n## Resultados\nLos resultados del ensayo mostraron mejoras significativas en varios parámetros para el grupo suplementado con SangrovitⓇ Extra:\n- **Mortalidad**: El grupo control presentó una mortalidad del 5.14%, mientras que el grupo SE100 mostró una reducción a 4.69%.\n- **Producción de huevos**: Durante el periodo de calor, la pérdida de producción fue del 21% en el grupo control, comparado con solo un 6% en el grupo SE100.\n- **Peso promedio de los huevos**: El grupo control tuvo un peso promedio de 42.7 g, mientras que el grupo SE100 alcanzó un promedio de 50.4 g.\n- **Huevos vendibles**: El grupo SE100 mostró un aumento del 0.8% en huevos vendibles.\n- **Consumo diario de alimento**: Las aves suplementadas con SangrovitⓇ Extra incrementaron su consumo diario de alimento en 13 g.\n\n## Conclusiones\nEl suplemento SangrovitⓇ Extra demostró ser efectivo en la mejora del rendimiento de las gallinas ponedoras bajo condiciones de estrés por calor. Se observó una reducción en la mortalidad, un aumento en la producción y el peso de los huevos, así como un incremento en el número de huevos vendibles. Además, el consumo diario de alimento también se incrementó, lo que sugiere una mejora en la eficiencia alimenticia durante el periodo de estrés térmico.\n\n## Observaciones\nEl ensayo se realizó en un entorno de campo en Polonia, y aunque los resultados son prometedores, se sugiere realizar estudios adicionales para confirmar estos hallazgos en diferentes condiciones climáticas y con otras especies de aves de corral. La información detallada sobre la dieta y las condiciones específicas del ensayo proporciona un contexto valioso para la interpretación de los resultados.'}
# {'paper_title': 'Effect of Sangrovit Supplementation to Dairy Cows on Performance and Somatic Cell Counts', 'synthesis': '## Introducción\nEl estudio titulado "Effect of Sangrovit Supplementation to Dairy Cows on Performance and Somatic Cell Counts" (Efecto de la Suplementación con Sangrovit en Vacas Lecheras sobre el Rendimiento y el Conteo de Células Somáticas) se llevó a cabo para evaluar los efectos de Sangrovit®, administrado a través de un bolus, en el rendimiento (producción de leche y componentes de la leche) y el conteo de células somáticas (SCC) de vacas lecheras en lactación. La hipótesis planteada fue que la suplementación con Sangrovit® comenzando en el período preparto aumentaría la producción de leche y mejoraría la salud de la ubre en vacas lecheras.\n\n## Objetivo\nEl objetivo principal del estudio fue determinar si la administración de Sangrovit® a vacas lecheras durante el período de transición y la lactancia temprana podría mejorar la productividad y reducir el SCC, especialmente bajo condiciones de estrés por calor.\n\n## Metodología\nEl estudio se realizó en la Universidad de Toulouse, Francia, y abarcó un periodo de tres años (2017-2019). Se incluyeron 1226 vacas lecheras de 30 granjas en Francia. Las vacas fueron emparejadas por número de lactación y fecha esperada de parto. Considerando la producción de leche de lactaciones previas y el SCC, las vacas fueron asignadas aleatoriamente a dos tratamientos:\n1. Control (n=613): sin administración de tratamiento.\n2. Sangrovit® (n=613): se administraron 2 bolus de Sangrovit® 21 días antes de la fecha esperada de parto.\n\nLa dosificación consistió en bolus diseñados para liberar un equivalente de 3 g/animal/día de Sangrovit® Extra durante 42 días y un equivalente de 1.5 g/animal/día durante 120 días.\n\n## Resultados\nLa producción de leche fue mayor en las vacas del grupo Sangrovit® (38.66 ± 0.59 kg) en comparación con el grupo control (38.66 ± 0.59 kg). Además, el SCC promedio y la proporción de vacas con SCC > 200x10³ fueron menores en las vacas suplementadas con Sangrovit® en comparación con las vacas del grupo control.\n\nDurante los meses de verano (abril-septiembre), se observó que Sangrovit® tenía un efecto más pronunciado, sugiriendo que los animales manejan mejor el estrés por calor. Los resultados mostraron una reducción significativa en el SCC y una mejora en la producción de leche durante estos meses.\n\n## Conclusiones\nLa suplementación con Sangrovit® durante el período de transición y la lactancia temprana puede considerarse una estrategia efectiva para mejorar la productividad y reducir el SCC en vacas lecheras. El efecto más pronunciado durante los meses de calor sugiere que Sangrovit® ayuda a las vacas a enfrentar mejor el estrés térmico.\n\n## Observaciones\nEl estudio no fue publicado y fue actualizado el 5 de abril de 2023. La investigación fue realizada por Phytobiotics Futterzusatzstoffe GmbH, ubicada en Eltville, Alemania. No se proporcionó información dietética adicional en el estudio.'}
# {'paper_title': 'The effect of combining Sangrovit with common coccidiosis intervention strategies', 'synthesis': '## Introducción\nEl estudio titulado "The effect of combining Sangrovit with common coccidiosis intervention strategies" se llevó a cabo en la Santa Livia Research Farm, ubicada en Rio Grande do Sul, Brasil, en el año 2019. Este trabajo de investigación se centra en evaluar el efecto de SangrovitⓇ Extra cuando se combina con estrategias comunes de intervención contra la coccidiosis en pollos de engorde, específicamente la variedad Cobb 500. La coccidiosis es una enfermedad parasitaria que afecta a las aves de corral, causando inflamación y pérdida de rendimiento.\n\n## Objetivo\nEl objetivo principal del estudio fue determinar si la adición de SangrovitⓇ Extra a diferentes estrategias de intervención contra la coccidiosis (químicos, ionóforos y vacunas) mejora el rendimiento de los pollos de engorde, medido a través de la eficiencia alimenticia, ganancia de peso corporal, mortalidad, integridad intestinal y respuesta inflamatoria.\n\n## Metodología\nEl ensayo se realizó durante 53 días, utilizando machos Cobb 500 alojados en corrales de piso con cama reutilizada y una densidad de población de 30 kg/m². Las dietas se basaron en maíz (61-74%) y harina de soja (22-33%), divididas en períodos de alimentación: inicio (d0-14), crecimiento (d15-28), finalización (d29-44) y retiro (d45-53). No se aplicó un desafío artificial, sino que se consideró el riesgo natural de infección.\n\nSe evaluaron diez tratamientos diferentes:\n1. Control negativo\n2. Control positivo con Nicarbazin (100 g/t alimento)\n3. Nicarbazin + 60 ppm SangrovitⓇ Extra\n4. Nicarbazin + 90 ppm SangrovitⓇ Extra\n5. Control positivo con Salinomycin (60 g/t alimento)\n6. Salinomycin + 60 ppm SangrovitⓇ Extra\n7. Salinomycin + 90 ppm SangrovitⓇ Extra\n8. Vacuna (Fortegra, aplicación ocular) + 0 ppm SangrovitⓇ Extra\n9. Vacuna + 60 ppm SangrovitⓇ Extra\n10. Vacuna + 90 ppm SangrovitⓇ Extra\n\nCada tratamiento tuvo 8 o 9 réplicas, con 18 aves por réplica, totalizando 1,584 aves en el estudio.\n\n## Resultados\n### Eficiencia Alimenticia (FCR)\n- El FCR mejoró con la adición de SangrovitⓇ en todos los tratamientos anticoccidiales. Los valores de FCR fueron:\n  - Control negativo: 1.87\n  - Nicarbazin: 1.83\n  - Nicarbazin + 60 ppm SangrovitⓇ: 1.79\n  - Salinomycin: 1.80\n  - Salinomycin + 60 ppm SangrovitⓇ: 1.77\n  - Vacuna + 90 ppm SangrovitⓇ: 1.80\n\n### Ganancia de Peso Corporal\n- La ganancia de peso corporal también mostró mejoras con SangrovitⓇ:\n  - Control negativo: 3,995 g\n  - Nicarbazin + 60 ppm SangrovitⓇ: 4,177 g\n  - Salinomycin + 60 ppm SangrovitⓇ: 4,084 g\n\n### Mortalidad\n- No se encontraron diferencias significativas en la mortalidad entre los grupos (p ≤ 0.945).\n\n### Integridad Intestinal\n- La integridad intestinal, medida por el contenido de FITC-dextran en suero, mejoró con SangrovitⓇ en aves vacunadas.\n\n### Respuesta Inflamatoria\n- La expresión de citocinas proinflamatorias (TNF-a) y antiinflamatorias (IL-10) fue menor en aves alimentadas con SangrovitⓇ, indicando propiedades antiinflamatorias.\n\n## Conclusiones\nEl estudio concluye que SangrovitⓇ Extra proporciona un efecto sinérgico cuando se combina con estrategias anticoccidiales, mejorando la eficiencia alimenticia y la ganancia de peso corporal, sin afectar la mortalidad. SangrovitⓇ no inhibe directamente a los coccidios, pero regula la respuesta inflamatoria, lo que resulta en un impacto positivo en el rendimiento de las aves.\n\n## Observaciones\n- El estudio fue realizado por Phytobiotics Futterzusatzstoffe GmbH, con sede en Alemania.\n- Los resultados sugieren que la suplementación con SangrovitⓇ puede ser una estrategia efectiva para mitigar los efectos negativos de la coccidiosis en la producción avícola.'}
# {'paper_title': 'Sangrovit® Extra improves feed intake in lactating sows and pre-weaning piglet performance', 'synthesis': '## Introducción\nEl estudio titulado "Sangrovit® Extra improves feed intake in lactating sows and pre-weaning piglet performance" se llevó a cabo en la Universidad de Lieja, Bélgica, en 2018. Este trabajo fue realizado por Phytobiotics Futterzusatzstoffe GmbH, con el objetivo de evaluar el impacto del suplemento Sangrovit® Extra en el rendimiento de cerdas lactantes y el desarrollo de lechones antes del destete.\n\n## Objetivo\nEl objetivo principal del estudio fue evaluar el rendimiento de crecimiento y el desarrollo de la barrera intestinal en lechones antes del destete, provenientes de cerdas suplementadas con Sangrovit® Extra. Los objetivos específicos incluyeron:\n- Evaluar el efecto de la suplementación con Sangrovit® Extra en el rendimiento de las cerdas hasta 7 días después del destete.\n- Evaluar la respuesta al estrés debido al parto.\n- Determinar la influencia de Sangrovit® Extra en la calidad del calostro y la leche de las cerdas.\n- Evaluar el desarrollo intestinal de los lechones.\n- Determinar la influencia de la suplementación en la salud y el rendimiento de crecimiento de los lechones.\n\n## Metodología\nEl ensayo se realizó con 24 cerdas Landrace, alojadas en grupos durante la gestación hasta una semana antes del parto. Las cerdas fueron asignadas aleatoriamente a tres tratamientos:\n- Control negativo (NC): cerdas no suplementadas.\n- SE-L: 150 ppm de Sangrovit® Extra desde el día -7 hasta el día +21.\n- SE-G+L: 90 ppm de Sangrovit® Extra desde el día 80 de gestación hasta el día -7, seguido de 150 ppm hasta el destete (día +21).\n\nSe evaluaron los siguientes parámetros:\n- Consumo de alimento de las cerdas (FI), pérdida de peso corporal y grosor de la grasa dorsal.\n- Ganancia diaria promedio (ADG) de los lechones hasta el destete.\n- Calidad del calostro y la leche (contenido de nitrógeno).\n\n## Resultados\n### Consumo de alimento y condición corporal de las cerdas\n- El consumo de alimento de las cerdas en maternidad mostró un incremento significativo en los grupos suplementados con Sangrovit® Extra, especialmente durante las primeras dos semanas post-parto.\n- Las cerdas suplementadas con Sangrovit® Extra perdieron menos peso durante la lactancia.\n- El grosor de la grasa dorsal mostró una tendencia a ser mayor en los grupos suplementados.\n\n### Calidad del calostro y la leche\n- El contenido de nitrógeno en el calostro fue significativamente mayor en las cerdas suplementadas (P = 0.008), lo que sugiere un mayor contenido proteico.\n- La leche también mostró un aumento en el contenido de nitrógeno, aunque con menor significancia (P = 0.057).\n\n### Rendimiento de los lechones\n- Los lechones de cerdas suplementadas con Sangrovit® Extra mostraron un mayor peso al destete, con un incremento de +790 g en el grupo SE-G+L y +490 g en el grupo SE-L.\n- La ganancia diaria promedio de los lechones fue superior en los grupos suplementados.\n\n## Conclusiones\nLa suplementación con Sangrovit® Extra en cerdas lactantes mejora significativamente el consumo de alimento durante las primeras dos semanas post-parto, lo que a su vez optimiza la calidad del calostro y la leche, y mejora la condición corporal de las cerdas para el siguiente ciclo reproductivo. Además, el aumento en la producción de leche apoya el crecimiento de los lechones, mejorando su peso al destete. El calostro de las cerdas suplementadas contiene más nitrógeno, lo que puede indicar un mayor contenido de proteínas, particularmente inmunoglobulinas.\n\n## Observaciones\nEl estudio no ha sido publicado y los datos crudos están disponibles para análisis adicionales. Se sugiere realizar análisis adicionales para confirmar el aumento de inmunoglobulinas en el calostro de cerdas suplementadas.'}
# {'paper_title': 'Sangrovit improves growth performance and gut health in heat stressed broiler chickens', 'synthesis': '## Introducción\n\nEl estudio titulado "Sangrovit improves growth performance and gut health in heat stressed broiler chickens" se centra en los efectos del estrés por calor (HS) en pollos de engorde y cómo la suplementación con alcaloides isoquinolínicos (IQs), específicamente Sangrovit Extra, puede mitigar estos efectos. El estrés por calor es conocido por impactar negativamente la función de la barrera intestinal y el rendimiento de los pollos de engorde, lo que lleva a una disminución en el rendimiento de crecimiento y alteraciones metabólicas e inmunológicas.\n\n## Objetivo\n\nEl objetivo principal del estudio fue evaluar el efecto de la suplementación con una mezcla estandarizada de alcaloides isoquinolínicos en el rendimiento de crecimiento y la integridad intestinal de pollos de engorde criados bajo condiciones de estrés por calor.\n\n## Metodología\n\n### Diseño Experimental\n\n- **Especie y Muestra**: 360 pollos de engorde machos Ross 308 de un día de edad.\n- **Ubicación**: Universidad de Tohoku, Japón.\n- **Duración del Estudio**: 42 días.\n- **Condiciones de Vivienda**: Alojados en corrales de piso.\n- **Dieta**: Basada en maíz, harina de soja y sorgo, sin aditivos antibióticos.\n- **Diseño de Tratamiento**: Diseño factorial 2x2:\n  - Control negativo en condiciones termoneutrales (TN) y bajo estrés por calor (HS).\n  - Suplementación con IQs (100 ppm) en condiciones TN y HS.\n- **Condiciones Ambientales**: TN (21.1-24.7 °C) y HS (30.0-33.3 °C).\n- **Repeticiones**: 6 repeticiones por tratamiento, 15 aves por repetición.\n\n### Medición de Parámetros\n\n- **Consumo de Alimento y Ganancia de Peso**: Monitoreados semanalmente.\n- **Función de Barrera Intestinal**: Evaluada mediante la administración de FITC-dextran.\n- **Parámetros Bioquímicos Plasmáticos**: Incluyendo corticosterona, ácido úrico, y TBARS.\n- **Expresión Génica Intestinal**: Medida mediante PCR en tiempo real para factores inflamatorios como IL-6, TL1A, e iNOS.\n\n## Resultados\n\n### Rendimiento de Crecimiento\n\n- **Ganancia de Peso Corporal (BWG)**: Aumentó significativamente en aves suplementadas con IQs bajo condiciones HS (P < 0.05).\n- **Consumo de Alimento (FI)**: Mayor en aves con IQs bajo HS comparado con el grupo control.\n- **Índice de Conversión Alimenticia (FCR)**: Mejorado en aves con IQs bajo HS (-11 unidades).\n\n### Parámetros Bioquímicos\n\n- **Corticosterona y Ácido Úrico**: Niveles elevados bajo HS, pero reducidos en aves con IQs.\n- **TBARS**: Indicador de daño oxidativo, elevado bajo HS pero no en aves con IQs.\n\n### Función de Barrera Intestinal\n\n- **FITC-dextran**: Niveles plasmáticos elevados bajo HS, indicando permeabilidad intestinal aumentada, pero no en aves con IQs.\n\n### Expresión Génica\n\n- **Citoquinas Inflamatorias**: IL-6 y TL1A aumentaron bajo HS, pero no en aves con IQs.\n- **iNOS**: Expresión reducida en aves con IQs bajo HS.\n\n## Conclusiones\n\nLa suplementación con alcaloides isoquinolínicos mejora el rendimiento de crecimiento de pollos de engorde bajo condiciones de estrés por calor. Los efectos beneficiosos se atribuyen a la mejora de la función de la barrera intestinal y la reducción de la inflamación sistémica. Estos resultados sugieren que los IQs pueden ser una estrategia efectiva para mitigar los efectos negativos del estrés por calor en la producción avícola.\n\n## Observaciones\n\n- **Mortalidad**: Disminuyó en 4.6 unidades en aves con IQs bajo HS.\n- **Puntuación de Producción**: Mejorada en aves con IQs, especialmente bajo HS.\n- **Retorno de Inversión (ROI)**: 4.8:1 bajo TN y 13.2:1 bajo HS, indicando beneficios económicos significativos.\n\nEste estudio fue publicado y realizado en colaboración con Phytobiotics Futterzusatzstoffe GmbH, Alemania, y la Universidad de Tohoku, Japón.'}
# {'paper_title': 'The use Sangrovit® Extra in horses - a safety study', 'synthesis': '## Introducción\nEl estudio titulado "The use Sangrovit® Extra in horses - a safety study" se llevó a cabo en una granja de caballos en Alemania, bajo la supervisión de un veterinario y la Universidad de Ciencias Aplicadas de Osnabrück. El objetivo principal fue evaluar la seguridad del suplemento Sangrovit® Extra en caballos. El estudio fue realizado por el Prof. H. Westendarp y se llevó a cabo en junio de 2018.\n\n## Objetivo\nEl objetivo del estudio fue determinar la seguridad del uso de Sangrovit® Extra en caballos, evaluando su impacto en parámetros fisiológicos y hematológicos, así como en el comportamiento alimenticio y la salud general de los animales.\n\n## Metodología\n### Diseño del Estudio\n- Tipo de ensayo: Ensayo de campo.\n- Diseño: Estudio ciego.\n- Duración: 8 semanas.\n- Localización: Granja de caballos en Alemania.\n- Animales: 21 caballos sanos, de edades entre 4 y 23 años.\n\n### Dieta y Tratamientos\n- Dieta: Heno del mismo lote y concentrado administrado a través de un alimentador automático 8 veces al día. Todos los caballos recibieron el mismo concentrado (11% de proteína cruda, 4.5% de grasa cruda, 4.5% de ceniza cruda). La cantidad de concentrado se ajustó al peso de cada caballo.\n- Cama: Paja de trigo descascarillada.\n- Tratamientos: \n  - I) Control negativo (NC).\n  - II) Dosis recomendada de Sangrovit® Extra (SRD) (5 mg/kg de peso corporal/animal/día).\n  - III) Dosis 10 veces la recomendada de Sangrovit® Extra (S10RD) (50 mg/kg de peso corporal/animal/día).\n  - Sangrovit® Extra se aplicó cada mañana sobre el concentrado según el peso corporal del caballo respectivo.\n\n### Parámetros Evaluados\n- Días 0, 28, 56: Peso corporal, frecuencia respiratoria, frecuencia cardíaca, temperatura corporal, mucosas, hemograma completo.\n- Diario: Ingesta de alimento, enfermedades, uso de medicamentos.\n- Día 56: Cuestionario para el propietario sobre componentes generales (comportamiento alimenticio, impresión física, consistencia fecal, etc.).\n\n## Resultados\n### Parámetros Fisiológicos y Hematológicos\n- No se observaron efectos adversos en el aumento de peso o la ingesta de alimento.\n- Todos los caballos consumieron la porción completa de concentrado cada día.\n- No hubo impacto de los tratamientos en las mucosas, frecuencia cardíaca o respiratoria, temperatura corporal o parámetros sanguíneos en los días 0, 28 y 56.\n\n### Hemograma Completo\n- Todos los parámetros del hemograma completo se mantuvieron dentro del rango de referencia para los tres grupos de tratamiento (NC, SRD, S10RD).\n\n### Datos de Peso Corporal\n- Día 0: NC 589 kg, SRD 588 kg, S10RD 577 kg.\n- Día 28: NC 596 kg, SRD 599 kg, S10RD 589 kg.\n- Día 56: NC 610 kg, SRD 609 kg, S10RD 602 kg.\n\n## Conclusiones\nSangrovit® Extra administrado a caballos de diferentes edades y razas, pero de peso similar, en la dosis recomendada y en una dosis 10 veces mayor, no mostró efectos adversos en el aumento de peso o la ingesta de alimento. Los caballos toleraron bien el olor y el sabor del suplemento. No se observó impacto en las mucosas, frecuencia cardíaca o respiratoria, temperatura corporal, ni en los parámetros sanguíneos evaluados. Sangrovit® Extra es una herramienta prometedora para apoyar la estabilidad intestinal en caballos sin riesgo de seguridad.\n\n## Observaciones\nEl estudio no fue publicado y no se proporcionaron datos crudos ni información dietética adicional. El ensayo fue actualizado el 21 de octubre de 2022.'}
# {'paper_title': 'Evaluation of the effects of Sangrovit® administration to dairy cows during summer conditions in combination with a DON-contaminated diet', 'synthesis': '## Introducción\nEl estudio titulado "Evaluation of the effects of Sangrovit® administration to dairy cows during summer conditions in combination with a DON-contaminated diet" se llevó a cabo para evaluar el impacto de la administración de Sangrovit® en el rendimiento de producción, eficiencia alimentaria, fertilidad, estado de salud y concentraciones de cortisol circulante en vacas lecheras durante condiciones de verano. Este estudio se realizó en una granja lechera comercial ubicada en la provincia de Brescia, Italia.\n\n## Objetivo\nEl objetivo principal del estudio fue determinar los efectos de la suplementación con Sangrovit® en vacas lecheras alimentadas con una dieta contaminada con DON (deoxinivalenol) durante el verano. Se buscó evaluar parámetros como el rendimiento de leche, el conteo de células somáticas (SCC), la eficiencia alimentaria, la respuesta al estrés y la fertilidad.\n\n## Metodología\nEl ensayo de campo incluyó vacas lecheras de raza Holstein-Friesian (HF), las cuales fueron equilibradas por paridad y días en leche (DIM) y asignadas aleatoriamente a dos grupos de tratamiento:\n- **Grupo Sangrovit® (n = 58):** Las vacas fueron suplementadas con 12 g/animal/día de Sangrovit® añadido al total de la ración mixta (TMR). El número promedio de lactación fue de 2.07 y el promedio de DIM fue de 48.8 días.\n- **Grupo Control (n = 58):** No se administró Sangrovit®. El número promedio de lactación fue de 2.02 y el promedio de DIM fue de 51.9 días.\n\nEl estudio comenzó en junio y tuvo una duración de 91 días (13 semanas). Se recomienda un período de adaptación al Sangrovit® de al menos 6, preferiblemente 8 semanas, para observar los efectos del producto.\n\n## Resultados\nLos resultados del estudio indicaron que la suplementación con Sangrovit® durante el verano, en combinación con una dieta contaminada con DON, tuvo los siguientes efectos:\n- **Rendimiento de leche diario (kg):** El grupo Sangrovit® mostró un rendimiento de 30.89 kg en comparación con 30.40 kg en el grupo control.\n- **Conteo de células somáticas (x1000):** El grupo Sangrovit® tuvo un SCC de 55.35, mientras que el grupo control presentó un SCC de 64.51.\n- **Eficiencia alimentaria:** Se observó una mejora en la eficiencia alimentaria en el grupo Sangrovit®.\n- **Respuesta al estrés:** Hubo una reducción en la respuesta al estrés en el grupo Sangrovit®.\n- **Estado de salud y fertilidad:** Se estabilizó el estado de salud y se observó un impacto positivo en la fertilidad.\n\n## Conclusiones\nLa administración de Sangrovit® a vacas lecheras durante el verano, junto con una dieta contaminada con DON, mejoró significativamente el rendimiento de leche, redujo el conteo de células somáticas, mejoró la eficiencia alimentaria, redujo la respuesta al estrés, estabilizó la salud y tuvo un impacto positivo en la fertilidad.\n\n## Observaciones\nEl estudio no ha sido publicado y no se dispone de datos en bruto. El ensayo fue realizado por PHYTOBIOTICS Futterzusatzstoffe GmbH, ubicada en Eltville, Alemania.'}
# {'paper_title': 'Sangrovit® Extra improves ruminal fermentation parameters under acidic and heat stress conditions – in vitro', 'synthesis': '## Introducción\nEl estudio titulado "Sangrovit® Extra improves ruminal fermentation parameters under acidic and heat stress conditions – in vitro" se llevó a cabo en la Universidad de Medicina Veterinaria de Viena, Austria, en marzo de 2019. Este trabajo de investigación se centra en evaluar los efectos del producto Sangrovit® Extra en la fermentación ruminal bajo condiciones de estrés ácido y térmico.\n\n## Objetivo\nEl objetivo principal del estudio fue determinar cómo diferentes niveles de inclusión de Sangrovit® Extra afectan los parámetros de fermentación ruminal, especialmente en condiciones de pH ácido y temperaturas elevadas.\n\n## Metodología\nSe utilizó un diseño experimental de cuadrado latino 2 x 2, empleando la técnica de simulación de rumen (Rusitec). Los niveles de inclusión de Sangrovit® Extra fueron de 0 g (control negativo), 1.5 g (bajo) y 3.0 g/animal/día (alto). Las condiciones experimentales incluyeron dos niveles de pH (normal: 6.6 y ácido: 6.0) y dos temperaturas (normal: 39.5°C y estrés térmico: 42.0°C).\n\n## Resultados\n1. **Producción de Propionato:** La inclusión baja de Sangrovit® Extra promovió la producción de propionato ruminal, proporcionando más sustrato para la gluconeogénesis hepática en todas las condiciones de incubación.\n2. **Concentración de Amoníaco:** Con una alta inclusión de Sangrovit® Extra, la concentración de amoníaco se redujo bajo condiciones de incubación ácida, lo que indica una mejora en la síntesis de proteína microbiana.\n3. **Formación de Metano:** La formación de metano se mitigó con una alta inclusión de Sangrovit® Extra bajo condiciones ácidas, independientemente de la temperatura de incubación. Este efecto se atribuye a una eficiencia microbiana mejorada, ya que no se encontró efecto en la degradabilidad de nutrientes.\n4. **Microbioma:** El microbioma fue afectado únicamente con altas tasas de inclusión de Sangrovit® Extra.\n\n## Conclusiones\nLa inclusión dietética de Sangrovit® Extra puede mejorar la fermentación ruminal incluso bajo condiciones de estrés térmico y ácido. Sin embargo, se requieren altas tasas de inclusión para afectar la formación de metano, la eficiencia del nitrógeno y el microbioma.\n\n## Observaciones\nEl estudio no fue publicado y se realizó en un entorno controlado de investigación en la Universidad de Medicina Veterinaria de Viena. Los datos crudos están disponibles, y se proporcionó información dietética como parte del estudio.'}
# {'paper_title': 'Comparing the effect of Sangrovit® and ZnO supplementation on diarrhea of post-weaning pigs', 'synthesis': '## Introducción\nEl óxido de zinc (ZnO) se utiliza como una estrategia nutricional para mejorar la salud intestinal en lechones después del destete. Es efectivo en el control de la diarrea y se usa como una alternativa a los antibióticos. Sin embargo, las altas dosis (2500-3000 ppm) de ZnO necesarias para influir positivamente en la incidencia de la diarrea post-destete (PWD) y el rendimiento del crecimiento representan un riesgo para el medio ambiente debido a los altos niveles de zinc excretados. Varios estudios han sugerido el uso de ácidos orgánicos, principalmente ácidos grasos de cadena media (MCFA), caprílico (C8) y cáprico (C10), como efectivos en la reducción de bacterias patógenas en cerdos, además de sus beneficios en el rendimiento del crecimiento. Nuestra hipótesis fue que el uso de Sangrovit® mejoraría los puntajes fecales de los lechones después del destete, así como reduciría la necesidad de tratamientos antibióticos.\n\n## Objetivo\nEl objetivo del estudio fue comparar el efecto de la suplementación con Sangrovit® y ZnO en la diarrea de lechones después del destete.\n\n## Metodología\n- **Especie**: Lechones (genética PIC, peso corporal 6.64 kg, edad 23±2 días, 50% machos castrados y 50% hembras).\n- **Duración del ensayo**: 8 semanas.\n- **Dieta**: Dietas Pre-Iniciador (23-42 días) e Iniciador (43-77 días), basadas en maíz y harina de soja.\n- **Instalaciones**: 12 corrales/tratamiento; 4 lechones/corral. Los corrales tenían un piso de plástico completamente ranurado, un área de 2.55 m², un comedero lineal (0.9 m) y un bebedero de tetina ajustable.\n- **Temperatura ambiente**: Registrada usando un registrador de datos.\n- **Parámetros evaluados**:\n  - Incidencia, duración y severidad de la diarrea.\n  - Uso de medicación.\n- **Tratamientos**:\n  1. Control negativo (CON; n = 60): dieta basal, no suplementada.\n  2. Ácidos orgánicos (OA; n = 60): dieta basal suplementada con 4000 g/ton de mezcla de OA (propiónico, butírico, cáprico y caprílico).\n  3. Sangrovit® (SAN; n = 60): dieta basal suplementada con 100 g/1000 l de agua de Sangrovit® WS durante los primeros 3 días después del destete y 300 g/ton de Sangrovit® Extra durante toda la duración del ensayo.\n  4. Control positivo (ZnO; n = 60): dieta basal suplementada con 3000 g/ton de ZnO durante 3 semanas.\n\n## Resultados\n- **Incidencia de diarrea (%) (nuevos casos/2 semanas)**:\n  - CON: 46.66%\n  - OA: 33.33%\n  - SAN: 23.33%\n  - ZnO: 6.66%\n- **Costo de medicación (USD) (costo de 1 dosis es 0.21 USD)**:\n  - CON: 10.4 USD\n  - OA: 7.03 USD\n  - SAN: 4.05 USD\n  - ZnO: 0.90 USD\n- Sangrovit® fue efectivo en reducir la incidencia de diarrea y disminuyó el número de casos en un 61% en comparación con el grupo de control. ZnO redujo el número de casos de diarrea en un 92% en comparación con el grupo de control. Los parámetros de rendimiento no fueron diferentes entre los grupos de tratamiento y todos los valores estuvieron dentro de los rangos normales según las tablas de referencia de PIC.\n- Los animales del grupo de control necesitaron más de una dosis de antibióticos, mientras que ninguno de los lechones de los grupos OA, SAN o ZnO requirió una segunda dosis. Esto significa que los animales que recibieron OA, ZnO o Sangrovit® pudieron recuperarse más rápido que los cerdos no suplementados y necesitaron menos antibióticos para el tratamiento, disminuyendo así los costos de medicación.\n\n## Conclusiones\nSangrovit® en lechones después del destete mejoró los puntajes fecales, los casos, la duración y la severidad de la diarrea y la necesidad de antibióticos. Aunque el ZnO mostró una mayor reducción en la incidencia de diarrea, Sangrovit® y los ácidos orgánicos también fueron efectivos, ofreciendo una alternativa potencialmente más sostenible.\n\n## Observaciones\nEl estudio se llevó a cabo en el AKEI Animal Research en Brasil y n ...
# {'paper_title': 'Effects of Sangrovit® Extra and Isoquinoline Alkaloids on Growth, Survival, and Immune Response of White Shrimp (Litopenaeus vannamei)', 'synthesis': '## Introducción\n\nEl uso de productos naturales derivados de plantas como aditivos alimentarios en la producción animal está ganando popularidad debido a sus múltiples actividades biológicas, como efectos antimicrobianos, antiinflamatorios, antioxidantes, inmunoestimulantes y estimulantes del apetito. Estos productos pueden mejorar el rendimiento del crecimiento y la salud general de los animales. En este contexto, los alcaloides isoquinolínicos (IQs) de Macleaya cordata y Sangrovit® Extra, un aditivo alimentario, han sido investigados por sus efectos en el rendimiento del crecimiento, la supervivencia, la respuesta inmune y la resistencia a infecciones en el camarón blanco del Pacífico (Litopenaeus vannamei).\n\n## Objetivo\n\n1. Determinar el efecto de Sangrovit® Extra en el crecimiento, la tasa de supervivencia y la expresión de genes relacionados con el sistema inmune en postlarvas de camarón blanco (Litopenaeus vannamei) criadas bajo condiciones de laboratorio.\n2. Evaluar el efecto de Sangrovit® Extra en el crecimiento, la tasa de supervivencia y la condición del hepatopáncreas e intestino de juveniles de camarón blanco desafiados con la bacteria Vibrio parahaemolyticus.\n3. Investigar los efectos de los alcaloides isoquinolínicos de Macleaya cordata en el rendimiento del crecimiento, la supervivencia, la respuesta inmune y la resistencia a la infección por Vibrio parahaemolyticus en camarones blancos del Pacífico.\n\n## Metodología\n\n### Experimento con Sangrovit® Extra\n\n- **Diseño del experimento:** Se realizaron dos ensayos. En el primero, se evaluó el efecto de Sangrovit® Extra en postlarvas de camarón blanco durante 30 días. En el segundo, se evaluó el efecto en juveniles desafiados con Vibrio parahaemolyticus durante 14 días.\n- **Condiciones del ensayo:** Se utilizaron postlarvas PL12 y juveniles saludables. La densidad fue de 150 PL/m² o 100 camarones/tanque. La salinidad del agua fue de 25-30 ppt y la temperatura de 29°C ± 1°C.\n- **Tratamientos:** Se administraron dietas con Sangrovit® Extra a 200 ppm y 300 ppm.\n- **Parámetros medidos:** Tasa de supervivencia, ganancia de peso, relación de conversión alimenticia (FCR), conteo total de hemocitos (THC), actividad fagocítica (PC), actividad de fenoloxidasa (PO) y actividad de superóxido dismutasa (SOD).\n\n### Experimento con Alcaloides Isoquinolínicos\n\n- **Diseño del experimento:** Se realizaron dos experimentos. En el primero, se evaluaron los efectos de IQs en el crecimiento, supervivencia y sistema inmune de camarones saludables durante 30 días. En el segundo, se evaluaron los efectos tras un desafío con V. parahaemolyticus durante 14 días.\n- **Condiciones del ensayo:** Se utilizaron postlarvas PL9. La temperatura del agua se mantuvo entre 26-27°C, con una salinidad de 25 ppt.\n- **Tratamientos:** Se administraron dietas con IQ-E a 200 y 300 mg/kg de alimento, e IQ-WS a 100 y 150 mg/kg de alimento.\n- **Parámetros medidos:** Tasa de supervivencia, ganancia de peso, THC, PC, PO y SOD.\n\n## Resultados\n\n### Resultados de Sangrovit® Extra\n\n- **Crecimiento y Supervivencia:** Los camarones alimentados con Sangrovit® Extra mostraron una tasa de supervivencia significativamente mayor (P<0.05) en comparación con el grupo control. No hubo diferencias significativas en el peso corporal promedio y FCR entre los grupos experimentales.\n- **Respuesta Inmune:** Los grupos alimentados con Sangrovit® Extra mostraron una respuesta inmune significativamente mayor, con un aumento del 68% en el conteo de hemocitos, 61% en la actividad fagocítica, 11% en la actividad de fenoloxidasa y 16% en la actividad de SOD.\n- **Condición del Hepatopáncreas e Intestino:** Los camarones desafiados con V. parahaemolyticus y alimentados con Sangrovit® Extra mostraron una mejor condición del hepatopáncreas e intestino,  ...
# {'paper_title': 'Performance of Slow-Growing Broiler Chickens is Positively Influenced by Isoquinoline Alkaloids', 'synthesis': '## Introducción\nEl bienestar animal en la producción avícola es una preocupación creciente entre los productores. En este contexto, las aves de crecimiento lento han captado la atención debido a su potencial para mejorar el bienestar animal. Este estudio se centra en evaluar el efecto de una mezcla estandarizada de alcaloides isoquinolínicos derivados de plantas (IQs, Sangrovit® Extra) en pollos de engorde de crecimiento lento, con un peso corporal objetivo de aproximadamente 1,500 g.\n\n## Objetivo\nEl objetivo del estudio fue evaluar el impacto de los alcaloides isoquinolínicos en el rendimiento de pollos de engorde de crecimiento lento, considerando aspectos como el peso corporal final, la conversión alimenticia (FCR), la mortalidad, y el índice de producción europeo.\n\n## Metodología\nSe utilizó un diseño factorial de dos factores: sexo (macho/hembra) y aditivo alimenticio (1) Control (CON), sin aditivo alimenticio, y 2) IQ: IQs (60 ppm, día 1-32). Se incluyeron 888 pollitos de un día de edad (raza JV, Hubbard), distribuidos aleatoriamente en grupos de prueba. Cada grupo consistió en 6 réplicas, con 37 aves por réplica. Las aves tuvieron acceso ad libitum a alimento suplementado con un coccidiostato. El ensayo se llevó a cabo durante 32 días, con un régimen de alimentación en cuatro etapas (iniciador: día 0-10; crecimiento: día 10-20; finalizador I: día 20-28; finalizador II: día 28-32; pellets).\n\n## Resultados\n- **Peso Corporal Final:** Los IQs mejoraron significativamente el peso corporal final de machos y hembras (p ≤ 0.05), alcanzando 1,499 g y 1,525 g respectivamente.\n- **Conversión Alimenticia (FCR):** No se observaron diferencias en la ingesta de alimento, pero el FCR mejoró en promedio en 3 unidades con la aplicación de IQs (p ≤ 0.05), siendo 1.59 para el control y 1.56 para el grupo con IQs.\n- **Mortalidad:** No se encontraron diferencias significativas en la mortalidad entre los grupos.\n- **Índice de Producción Europeo:** Se observó un índice de producción europeo más alto en aves suplementadas con IQs, con valores de 275 y 286 respectivamente.\n- **Pododermatitis:** Los machos mostraron una incidencia significativamente mayor de lesiones severas de pododermatitis (p ≤ 0.0001), aunque la adición de IQs tendió a disminuir estas lesiones en ambos sexos (p ≥ 0.05).\n\n## Conclusiones\nLa utilización de una mezcla estandarizada de alcaloides isoquinolínicos derivados de plantas mejora el rendimiento de los pollos de engorde de crecimiento lento, apoyando así una producción económica en conceptos que priorizan el bienestar animal mediante la elección de genéticas de crecimiento lento. Los IQs ofrecen una solución prometedora para mejorar el peso corporal final y la eficiencia alimenticia sin afectar negativamente la mortalidad.\n\n## Observaciones\nEl estudio se llevó a cabo en Francia, en las instalaciones de Zootests, y los datos crudos están disponibles. Las aves fueron vacunadas contra IB y IBD, y se mantuvieron en corrales de piso con cama fresca no enmendada durante el estudio. El ensayo fue publicado y los resultados fueron actualizados el 22 de noviembre de 2022.'}
# ...
# {'paper_title': 'Effect of Sangrovit® Feed on feed intake and growth of post-weaning piglets', 'synthesis': '## Introducción\nEl estudio titulado "Effect of Sangrovit® Feed on feed intake and growth of post-weaning piglets" se llevó a cabo para evaluar el impacto de la formulación Sangrovit® Feed en el rendimiento de lechones después del destete. Este ensayo se realizó en instalaciones de investigación en Dinamarca, bajo la supervisión de Phytobiotics Futterzusatzstoffe GmbH, una empresa con sede en Alemania. La investigación se centró en la especie porcina, específicamente en lechones DanBred x Duroc, con una proporción de machos a hembras de 1:1.\n\n## Objetivo\nEl objetivo principal del estudio fue evaluar el efecto de Sangrovit® Feed en la ingesta de alimento y el crecimiento de lechones post-destete. Se buscó determinar si esta formulación mejoraba el rendimiento de los lechones en términos de ganancia diaria promedio (ADG), ingesta diaria promedio de alimento (ADFI) y la relación de conversión alimenticia (FCR).\n\n## Metodología\nEl ensayo incluyó a 600 lechones de 28 días de edad con un peso corporal inicial promedio de 7.7 kg. Los animales fueron alojados en 60 corrales, con 10 lechones por corral, y tuvieron acceso ad libitum a alimento y agua. El estudio se extendió por 42 días, divididos en dos fases: pre-iniciador (días 0-14) e iniciador (días 14-42). Los lechones fueron alimentados con dietas en harina basadas en trigo, cebada, harina de soja y maíz, que contenían fitasa y acidificantes como ácido cítrico, ácido fosfórico y Ca-formiato.\n\nSe establecieron dos grupos de tratamiento:\n1. Control negativo\n2. Sangrovit® Feed (200 ppm)\n\n## Resultados\nLos resultados mostraron que el grupo alimentado con Sangrovit® Feed tuvo una mejora significativa en la ganancia diaria promedio (ADG) y en la ingesta diaria promedio de alimento (ADFI) en comparación con el grupo control. Sin embargo, no se observó un efecto estadísticamente significativo en la relación de conversión alimenticia (FCR).\n\n- **Ganancia Diaria Promedio (ADG):**\n  - Control: 478 g\n  - Sangrovit® Feed: 529 g (p < 0.05)\n\n- **Ingesta Diaria Promedio de Alimento (ADFI):**\n  - Control: 691 g\n  - Sangrovit® Feed: 758 g\n\n- **Relación de Conversión Alimenticia (FCR):**\n  - Control: 1.44\n  - Sangrovit® Feed: 1.43\n\nAdemás, se observó una mejora en la calidad de las heces en el grupo tratado con Sangrovit® Feed, especialmente durante la fase pre-iniciador, con una puntuación fecal de 0.7 en comparación con 0.9 del grupo control (p < 0.001).\n\n## Conclusiones\nSangrovit® Feed demostró ser eficaz para mejorar la ingesta de alimento y la ganancia diaria promedio en lechones destetados. Aunque la relación de conversión alimenticia no mostró diferencias significativas, el aumento significativo de ADG en la fase de iniciador sugiere que una mejor ingesta de alimento y crecimiento pueden tener beneficios a medio y largo plazo. Todos los lechones del estudio se mantuvieron saludables, sin incidencia de diarrea, y se observó una mejora estadísticamente significativa en la calidad de las heces durante la fase pre-iniciador.\n\n## Observaciones\nEl estudio no fue publicado y los datos brutos no están disponibles. La investigación fue actualizada por última vez el 17 de mayo de 2023.'}
# {'paper_title': 'The effect of Sangrovit® Extra supplementation on nutrient absorption and gut morphology of growing pigs fed a corn-soybean diet', 'synthesis': '## Introducción\n\nDebido a las restricciones en el uso de antibióticos, se necesitan estrategias alternativas para mejorar el rendimiento del crecimiento y la salud gastrointestinal en cerdos. Los alcaloides isoquinolínicos (IQ) poseen propiedades beneficiosas, tales como la reducción de la inflamación, la mejora de la función de la barrera intestinal y la mejora de la digestibilidad aparente ileal de aminoácidos (AA) y almidón. La inclusión de IQ en dietas de harina de maíz y soja puede resultar en un mejor rendimiento de crecimiento y salud intestinal debido a su efecto antiinflamatorio.\n\n## Objetivo\n\nProbar la hipótesis de que la inclusión de alcaloides isoquinolínicos (Sangrovit® Extra) en dietas de harina de maíz y soja mejorará el rendimiento del crecimiento y la salud intestinal de los lechones.\n\n## Metodología\n\n### Animales\n\n- Se utilizaron 160 cerdos con un peso corporal inicial de 6.33 ± 0.61 kg.\n- Diseño de bloques completos al azar con 4 tratamientos, 4 cerdos por corral y 10 corrales replicados por tratamiento.\n\n### Tratamientos\n\n1. Control (CON; n=10; dieta basal + 0 mg/kg IQ)\n2. SE90 (n=10; dieta basal + 90 mg/kg IQ)\n3. SE180 (n=10; dieta basal + 180 mg/kg IQ)\n4. SE360 (n=10; dieta basal + 360 mg/kg IQ)\n\n### Fases\n\n- Fase 1: día 0 a día 8\n- Fase 2: día 8 a día 21\n- Fase 3: día 21 a día 34\n\n### Alimentación y Recolección de Muestras\n\n- Pesos individuales de los cerdos (días 0, 8, 21, 34)\n- Asignaciones diarias de alimento\n- Recolección de muestras de sangre (días 8, 21, 34)\n\n### Mediciones\n\n- Ganancia diaria promedio (ADG), consumo diario promedio de alimento (ADFI), relación ganancia/alimento (G:F)\n- Morfología del íleon\n- Nitrógeno ureico en plasma y proteína total\n\n## Resultados\n\n### Nitrógeno Ureico en Plasma y Proteína Total\n\n- La inclusión de IQ mejoró la absorción de aminoácidos, evidenciada por un aumento en el nitrógeno ureico en plasma y la proteína total.\n\n### Consumo Diario Promedio de Alimento (ADFI) y Ganancia Diaria Promedio (ADG)\n\n- No se observó efecto de los IQ en la tasa de crecimiento general de los cerdos.\n\n### Relación Ganancia/Alimento (G:F)\n\n- La relación G:F aumentó en la fase 3 con la inclusión de 90, 180 o 360 mg/kg de IQ en la dieta.\n\n### Morfología del Íleon\n\n- Los IQ disminuyeron la profundidad de las criptas y el grosor de la lámina propia, indicando una reducción de la inflamación.\n\n## Conclusiones\n\n- Los alcaloides isoquinolínicos no afectaron la tasa de crecimiento general de los cerdos.\n- La inclusión de IQ en la dieta mejoró la relación G:F en la fase 3.\n- La absorción de aminoácidos se mejoró con la inclusión de IQ, como lo demuestra el aumento del nitrógeno ureico en plasma y la proteína total.\n- Los IQ redujeron la profundidad de las criptas y el grosor de la lámina propia, lo que indica una disminución de la inflamación.\n\n## Observaciones\n\n- El estudio fue realizado en la Universidad de Illinois, Estados Unidos, y no ha sido publicado hasta la fecha de la última actualización el 31 de octubre de 2022.\n- Los resultados sugieren que los alcaloides isoquinolínicos pueden ser una alternativa viable a los antibióticos para mejorar la salud intestinal y el rendimiento del crecimiento en cerdos.'}
# {'paper_title': 'Isoquinoline Alkaloids Improve Performance and Egg Quality in Laying Hens in the Late Stage of Production', 'synthesis': '## Introducción\n\nEl uso de aditivos alimentarios es una estrategia común para optimizar el rendimiento y el bienestar de los animales, especialmente en gallinas ponedoras durante las etapas finales de producción. Los compuestos fitogénicos específicos, como los alcaloides isoquinolínicos (IQs), son conocidos por sus propiedades antiinflamatorias y sus efectos positivos en la salud intestinal. Este estudio se centra en evaluar el efecto de una mezcla estandarizada de alcaloides isoquinolínicos derivados de plantas, comercialmente conocida como Sangrovit® Extra, en gallinas ponedoras durante la fase tardía de producción.\n\n## Objetivo\n\nEl objetivo del estudio fue determinar el efecto de la suplementación con una mezcla estandarizada de alcaloides isoquinolínicos en el rendimiento y la calidad del huevo de gallinas ponedoras en la etapa tardía de producción.\n\n## Metodología\n\nSe utilizaron 96 gallinas ponedoras de la línea Hy-Line, distribuidas aleatoriamente en dos tratamientos: un grupo control sin aditivos y un grupo experimental con 120 g/t de Sangrovit® Extra. Cada tratamiento contó con 4 réplicas de 12 gallinas cada una. Las aves fueron mantenidas en jaulas y alimentadas con dietas basadas en maíz y harina de soja durante un periodo de 6 semanas, comenzando a las 70 semanas de edad. Se midieron semanalmente parámetros de rendimiento, consumo de alimento y calidad del huevo. Al final del ensayo, se seleccionaron aleatoriamente 4 aves de cada tratamiento para evaluar la altura de las vellosidades y la relación altura de vellosidades:profundidad de criptas en el yeyuno e íleon.\n\n## Resultados\n\n- **Producción de huevos:** La producción de huevos fue significativamente mayor en las gallinas alimentadas con IQs, alcanzando un 74.7% en comparación con el 70.9% del grupo control (p < 0.05).\n- **Masa de huevo:** La masa de huevo también se incrementó en el grupo tratado con IQs, con un promedio de 338 g frente a 320 g en el grupo control (p > 0.05).\n- **Conversión alimenticia (FCR):** Las aves tratadas con IQs mostraron una mejora significativa en la FCR, con valores de 2.13 frente a 2.23 en el grupo control (p < 0.05).\n- **Calidad del huevo:** Las unidades Haugh, la resistencia de la cáscara del huevo y el color de la yema fueron numéricamente superiores en las gallinas alimentadas con IQs, indicando una mejor calidad del producto (p > 0.05).\n- **Morfología intestinal:** La altura de las vellosidades y la relación altura de vellosidades:profundidad de criptas fueron significativamente mejores en las aves tratadas con IQs en comparación con el grupo control (p < 0.05).\n\n## Conclusiones\n\nLa suplementación con alcaloides isoquinolínicos ofrece una solución económica para mejorar el rendimiento y la calidad del huevo en gallinas ponedoras durante la etapa tardía de producción. Los resultados indican mejoras significativas en la producción de huevos, la masa de huevo, la conversión alimenticia y la calidad del huevo, así como en la integridad intestinal.\n\n## Observaciones\n\n- El estudio se llevó a cabo en la Universidad Nacional de Pingtung, Taiwán, y fue publicado en el marco del 21º Simposio Europeo sobre Nutrición Avícola.\n- Se observó una mejora en la absorción de nutrientes, lo que se reflejó en la resistencia de la cáscara del huevo y el color de la yema.\n- Los resultados son consistentes con estudios previos que destacan los beneficios de los IQs en la salud intestinal y el rendimiento de las aves.'}
# {'paper_title': 'Effectiveness of SangrovitⓇ Extra to Control Salmonella Heidelberg in Broilers', 'synthesis': '## Introducción\n\nSalmonelosis es una de las enfermedades transmitidas por alimentos más comunes a nivel mundial, con millones de casos reportados anualmente. En los Estados Unidos, Salmonella heidelberg es una cepa comúnmente aislada en personas que sufren de salmonelosis, y es conocida por su resistencia creciente a los antibióticos. La transmisión de esta bacteria a los humanos puede ocurrir a través de productos avícolas, donde las infecciones en pollos suelen ser asintomáticas. Este estudio se centra en evaluar la efectividad de SangrovitⓇ Extra, un aditivo alimenticio derivado de alcaloides isoquinolínicos, para controlar Salmonella heidelberg en pollos de engorde.\n\n## Objetivo\n\nEl objetivo del estudio fue investigar el efecto de una mezcla estandarizada de alcaloides isoquinolínicos derivados de plantas (IQs, Sangrovit® Extra) en pollos de engorde infectados con Salmonella enterica serovar Heidelberg, con el fin de reducir la prevalencia de la bacteria y mejorar la seguridad alimentaria.\n\n## Metodología\n\n### Diseño del Estudio\n\n- **Especie:** Pollos de engorde (Ross 308)\n- **Número de animales:** 1,200 machos, día de eclosión\n- **Ubicación:** Southern Poultry Research Group, USA\n- **Duración del ensayo:** 35 días\n- **Vacunación:** Contra la enfermedad de Marek y coccidiosis\n- **Dieta:** Alimentación en tres etapas (iniciador: día 0-14, crecimiento: día 14-28, finalización: día 28-35) con alimento no medicado\n- **Alojamiento:** En corrales de piso con cama fresca, 50 aves por corral, 12 corrales por tratamiento\n\n### Inducción de la Enfermedad y Muestreo\n\n- **Día 4:** 13 pollos por corral fueron etiquetados, codificados por color y dosificados oralmente con 4 × 10^5 CFU/ml de Salmonella Heidelberg resistente al ácido nalidíxico.\n- **Día 14 y 35:** Se recolectaron muestras de botas para determinar la contaminación ambiental por Salmonella.\n- **Día 35:** Se sacrificaron 10 aves no etiquetadas por corral para la remoción de cecas y análisis de Salmonella.\n\n### Tratamientos\n\n1. **Control Negativo (NC):** Sin aditivo\n2. **SangrovitⓇ Extra (SE):** 120 ppm de SangrovitⓇ Extra por tonelada de alimento\n\n## Resultados\n\n### Ganancia de Peso y Consumo de Alimento\n\n- **Ganancia de peso promedio (g):** Control: 46.54, Sangrovit: 46.40\n- **Consumo de alimento promedio:** No se observaron diferencias significativas (p > 0.05)\n- **Índice de Conversión Alimenticia (FCR):** Control: 1.80, Sangrovit: 1.74 (mejora significativa, p < 0.05)\n\n### Prevalencia y Conteo de Salmonella\n\n- **Muestras de botas positivas (%):** Control: 100%, Sangrovit: 87.5%\n- **Conteo de Salmonella en cecas (Log 10 MPN/g):** Control: 0.55, Sangrovit: 0.40\n- **Reducción en prevalencia de Salmonella:** 10%\n- **Reducción en conteo de Salmonella:** 28%\n\n## Conclusiones\n\nEl uso de SangrovitⓇ Extra en pollos de engorde desafiados con Salmonella Heidelberg resultó en una mejora significativa en la eficiencia alimenticia y una reducción en la prevalencia y conteo de Salmonella. Esto no solo mejora la seguridad alimentaria al reducir el riesgo de infección humana, sino que también disminuye la presión de patógenos en el ambiente avícola, especialmente en sistemas que reutilizan la cama. SangrovitⓇ Extra se presenta como un aditivo alimenticio valioso para mejorar la producción avícola económica y segura.\n\n## Observaciones\n\nEl estudio fue realizado en una instalación de investigación en los Estados Unidos y los resultados fueron publicados. Los datos crudos del estudio están disponibles y el ensayo fue actualizado por última vez el 28 de noviembre de 2022.'}
